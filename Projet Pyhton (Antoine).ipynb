# %% [markdown]
# ## <center>HEC Montréal, Hiver 2022<br><br>TECH 20704<br>_Principes de la programmation en gestion_</center>
# ### <center>PROJET</center>
# <center><text-align>Antoine Bilodeau : MATRICULE<br>Lauie-Anne Jones : MATRICULE<br>Sarah McCarthy : MATRICULE<br>Paul-Anoine Roberge : 11257064</text-align></center>

# %%
import requests as rq
import json as js
import pandas as pd
import seaborn as sns

# %%
cyclist = pd.read_csv("Cyclists.csv", encoding='utf-8')

pd. set_option('display.max_columns', 500)
cyclist
# Out:
#                  X             Y    INDEX_      ACCNUM  YEAR  \
# 0    -8.849469e+06  5.415628e+06   7805822     1350654  2013
# 1    -8.838276e+06  5.411275e+06   7812849     1353734  2013
# 2    -8.838276e+06  5.411275e+06   7812850     1353734  2013
# 3    -8.838276e+06  5.411275e+06   7812851     1353734  2013
# 4    -8.838276e+06  5.411275e+06   7812852     1353734  2013
# ...            ...           ...       ...         ...   ...
# 1774 -8.852566e+06  5.419712e+06  80951003  8001574808  2018
# 1775 -8.845371e+06  5.423861e+06  80951038  8001650785  2018
# 1776 -8.845371e+06  5.423861e+06  80951039  8001650785  2018
# 1777 -8.845371e+06  5.423861e+06  80951040  8001650785  2018
# 1778 -8.823412e+06  5.437636e+06  80950662  8001679287  2018
#
#                         DATE  TIME  HOUR         STREET1            STREET2  \
# 0     2013/03/30 04:00:00+00  1214    12         JANE ST       DALRYMPLE DR
# 1     2013/04/04 04:00:00+00  2000    20      QUEEN St W        SPADINA Ave
# 2     2013/04/04 04:00:00+00  2000    20      QUEEN St W        SPADINA Ave
# 3     2013/04/04 04:00:00+00  2000    20      QUEEN St W        SPADINA Ave
# 4     2013/04/04 04:00:00+00  2000    20      QUEEN St W        SPADINA Ave
# ...                      ...   ...   ...             ...                ...
# 1774  2018/08/25 04:00:00+00  2300    23       CHURCH ST           CROSS ST
# 1775  2018/09/06 04:00:00+00  1310    13      ANTHONY RD  NAJIB ABBOUD LANE
# 1776  2018/09/06 04:00:00+00  1310    13      ANTHONY RD  NAJIB ABBOUD LANE
# 1777  2018/09/06 04:00:00+00  1310    13      ANTHONY RD  NAJIB ABBOUD LANE
# 1778  2018/09/10 04:00:00+00  1957    19  MIDDLEFIELD RD       MCNICOLL AVE
#
#             OFFSET      ROAD_CLASS               DISTRICT WARDNUM DIVISION  \
# 0           <Null>  Major Arterial         Etobicoke York       5       12
# 1           <Null>  Major Arterial  Toronto and East York      10       52
# 2           <Null>  Major Arterial  Toronto and East York      10       52
# 3           <Null>  Major Arterial  Toronto and East York      10       52
# 4           <Null>  Major Arterial  Toronto and East York      10       52
# ...            ...             ...                    ...     ...      ...
# 1774        <Null>       Collector         Etobicoke York       5       12
# 1775        <Null>           Local             North York       6       32
# 1776        <Null>           Local             North York       6       32
# 1777        <Null>           Local             North York       6       32
# 1778  1 m North of  Minor Arterial            Scarborough      23       42
#
#        LATITUDE  LONGITUDE      LOCCOORD            ACCLOC        TRAFFCTL  \
# 0     43.677233 -79.496135  Intersection   At Intersection      No Control
# 1     43.648944 -79.395587     Mid-Block            <Null>      No Control
# 2     43.648944 -79.395587     Mid-Block            <Null>      No Control
# 3     43.648944 -79.395587     Mid-Block            <Null>      No Control
# 4     43.648944 -79.395587     Mid-Block            <Null>      No Control
# ...         ...        ...           ...               ...             ...
# 1774  43.703757 -79.523952  Intersection   At Intersection      No Control
# 1775  43.730696 -79.459316     Mid-Block  Non Intersection      No Control
# 1776  43.730696 -79.459316     Mid-Block  Non Intersection      No Control
# 1777  43.730696 -79.459316     Mid-Block  Non Intersection      No Control
# 1778  43.820048 -79.262058  Intersection   At Intersection  Traffic Signal
#
#      VISIBILITY             LIGHT RDSFCOND           ACCLASS  \
# 0         Clear          Daylight      Dry  Non-Fatal Injury
# 1         Clear  Dusk, artificial      Dry  Non-Fatal Injury
# 2         Clear  Dusk, artificial      Dry  Non-Fatal Injury
# 3         Clear  Dusk, artificial      Dry  Non-Fatal Injury
# 4         Clear  Dusk, artificial      Dry  Non-Fatal Injury
# ...         ...               ...      ...               ...
# 1774      Clear  Dark, artificial      Dry  Non-Fatal Injury
# 1775      Clear          Daylight      Dry  Non-Fatal Injury
# 1776      Clear          Daylight      Dry  Non-Fatal Injury
# 1777      Clear          Daylight      Dry  Non-Fatal Injury
# 1778       Rain  Dusk, artificial      Wet  Non-Fatal Injury
#
#                IMPACTYPE        INVTYPE    INVAGE  INJURY FATAL_NO INITDIR  \
# 0     Cyclist Collisions        Cyclist  40 to 44   Major   <Null>   South
# 1            Approaching  Vehicle Owner   unknown  <Null>   <Null>  <Null>
# 2            Approaching         Driver  25 to 29    None   <Null>    West
# 3            Approaching      Passenger  55 to 59   Minor   <Null>  <Null>
# 4            Approaching   Moped Driver  55 to 59   Major   <Null>    East
# ...                  ...            ...       ...     ...      ...     ...
# 1774  Cyclist Collisions        Cyclist  40 to 44   Major   <Null>    West
# 1775  Cyclist Collisions        Cyclist  30 to 34   Major   <Null>   South
# 1776  Cyclist Collisions         Driver  30 to 34    None   <Null>    East
# 1777  Cyclist Collisions      Passenger  45 to 49    None   <Null>  <Null>
# 1778  Cyclist Collisions        Cyclist  55 to 59   Major   <Null>    West
#
#                         VEHTYPE    MANOEUVER           DRIVACT DRIVCOND  \
# 0                       Bicycle  Going Ahead            <Null>   <Null>
# 1                        <Null>       <Null>            <Null>   <Null>
# 2                    Street Car  Going Ahead  Driving Properly   Normal
# 3                        <Null>       <Null>            <Null>   <Null>
# 4                         Moped  Going Ahead            <Null>   <Null>
# ...                         ...          ...               ...      ...
# 1774                    Bicycle  Going Ahead            <Null>   <Null>
# 1775                    Bicycle  Going Ahead            <Null>   <Null>
# 1776  Automobile, Station Wagon  Going Ahead  Driving Properly   Normal
# 1777                     <Null>       <Null>            <Null>   <Null>
# 1778                    Bicycle  Going Ahead            <Null>   <Null>
#
#      PEDTYPE  PEDACT PEDCOND  \
# 0     <Null>  <Null>  <Null>
# 1     <Null>  <Null>  <Null>
# 2     <Null>  <Null>  <Null>
# 3     <Null>  <Null>  <Null>
# 4     <Null>  <Null>  <Null>
# ...      ...     ...     ...
# 1774  <Null>  <Null>  <Null>
# 1775  <Null>  <Null>  <Null>
# 1776  <Null>  <Null>  <Null>
# 1777  <Null>  <Null>  <Null>
# 1778  <Null>  <Null>  <Null>
#
#                                              CYCLISTYPE  \
# 0            Motorist turned left across cyclists path.
# 1                                                <Null>
# 2                                                <Null>
# 3                                                <Null>
# 4                                                <Null>
# ...                                                 ...
# 1774         Motorist turned left across cyclists path.
# 1775  Cyclist without ROW rides into path of motoris...
# 1776                                             <Null>
# 1777                                             <Null>
# 1778  Cyclist without ROW rides into path of motoris...
#
#                             CYCACT      CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE  \
# 0                 Driving Properly       Normal     <Null>     Yes        Yes
# 1                           <Null>       <Null>     <Null>     Yes     <Null>
# 2                           <Null>       <Null>     <Null>     Yes     <Null>
# 3                           <Null>       <Null>     <Null>     Yes     <Null>
# 4                           <Null>       <Null>     <Null>     Yes     <Null>
# ...                            ...          ...        ...     ...        ...
# 1774              Driving Properly       Normal     <Null>     Yes        Yes
# 1775  Failed to Yield Right of Way  Inattentive     <Null>     Yes        Yes
# 1776                        <Null>       <Null>     <Null>     Yes        Yes
# 1777                        <Null>       <Null>     <Null>     Yes        Yes
# 1778     Disobeyed Traffic Control      Unknown     <Null>     Yes        Yes
#
#      MOTORCYCLE   TRUCK TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV  \
# 0        <Null>  <Null>        <Null>    <Null>    <Null>   <Null>     Yes
# 1        <Null>  <Null>           Yes    <Null>       Yes   <Null>  <Null>
# 2        <Null>  <Null>           Yes    <Null>       Yes   <Null>  <Null>
# 3        <Null>  <Null>           Yes    <Null>       Yes   <Null>  <Null>
# 4        <Null>  <Null>           Yes    <Null>       Yes   <Null>  <Null>
# ...         ...     ...           ...       ...       ...      ...     ...
# 1774     <Null>  <Null>        <Null>    <Null>    <Null>   <Null>  <Null>
# 1775     <Null>  <Null>        <Null>    <Null>       Yes   <Null>  <Null>
# 1776     <Null>  <Null>        <Null>    <Null>       Yes   <Null>  <Null>
# 1777     <Null>  <Null>        <Null>    <Null>       Yes   <Null>  <Null>
# 1778     <Null>  <Null>        <Null>    <Null>    <Null>   <Null>  <Null>
#
#      REDLIGHT ALCOHOL DISABILITY POLICE_DIVISION  HOOD_ID  \
# 0      <Null>  <Null>     <Null>             D12      111
# 1      <Null>  <Null>     <Null>             D52       78
# 2      <Null>  <Null>     <Null>             D52       78
# 3      <Null>  <Null>     <Null>             D52       78
# 4      <Null>  <Null>     <Null>             D52       78
# ...       ...     ...        ...             ...      ...
# 1774   <Null>  <Null>     <Null>             D12      113
# 1775   <Null>  <Null>     <Null>             D32       26
# 1776   <Null>  <Null>     <Null>             D32       26
# 1777   <Null>  <Null>     <Null>             D32       26
# 1778   <Null>  <Null>     <Null>             D42      130
#
#                   NEIGHBOURHOOD  ObjectId
# 0       Rockcliffe-Smythe (111)         1
# 1     Kensington-Chinatown (78)         2
# 2     Kensington-Chinatown (78)         3
# 3     Kensington-Chinatown (78)         4
# 4     Kensington-Chinatown (78)         5
# ...                         ...       ...
# 1774               Weston (113)      1775
# 1775  Downsview-Roding-CFB (26)      1776
# 1776  Downsview-Roding-CFB (26)      1777
# 1777  Downsview-Roding-CFB (26)      1778
# 1778             Milliken (130)      1779
#
# [1779 rows x 57 columns]

# %%
cyclist.drop('X', inplace=True, axis=1)
cyclist.drop('Y', inplace=True, axis=1)

# %%
cyclist
# Out:
#         INDEX_      ACCNUM  YEAR                    DATE  TIME  HOUR  \
# 0      7805822     1350654  2013  2013/03/30 04:00:00+00  1214    12
# 1      7812849     1353734  2013  2013/04/04 04:00:00+00  2000    20
# 2      7812850     1353734  2013  2013/04/04 04:00:00+00  2000    20
# 3      7812851     1353734  2013  2013/04/04 04:00:00+00  2000    20
# 4      7812852     1353734  2013  2013/04/04 04:00:00+00  2000    20
# ...        ...         ...   ...                     ...   ...   ...
# 1774  80951003  8001574808  2018  2018/08/25 04:00:00+00  2300    23
# 1775  80951038  8001650785  2018  2018/09/06 04:00:00+00  1310    13
# 1776  80951039  8001650785  2018  2018/09/06 04:00:00+00  1310    13
# 1777  80951040  8001650785  2018  2018/09/06 04:00:00+00  1310    13
# 1778  80950662  8001679287  2018  2018/09/10 04:00:00+00  1957    19
#
#              STREET1            STREET2        OFFSET      ROAD_CLASS  \
# 0            JANE ST       DALRYMPLE DR        <Null>  Major Arterial
# 1         QUEEN St W        SPADINA Ave        <Null>  Major Arterial
# 2         QUEEN St W        SPADINA Ave        <Null>  Major Arterial
# 3         QUEEN St W        SPADINA Ave        <Null>  Major Arterial
# 4         QUEEN St W        SPADINA Ave        <Null>  Major Arterial
# ...              ...                ...           ...             ...
# 1774       CHURCH ST           CROSS ST        <Null>       Collector
# 1775      ANTHONY RD  NAJIB ABBOUD LANE        <Null>           Local
# 1776      ANTHONY RD  NAJIB ABBOUD LANE        <Null>           Local
# 1777      ANTHONY RD  NAJIB ABBOUD LANE        <Null>           Local
# 1778  MIDDLEFIELD RD       MCNICOLL AVE  1 m North of  Minor Arterial
#
#                    DISTRICT WARDNUM DIVISION   LATITUDE  LONGITUDE  \
# 0            Etobicoke York       5       12  43.677233 -79.496135
# 1     Toronto and East York      10       52  43.648944 -79.395587
# 2     Toronto and East York      10       52  43.648944 -79.395587
# 3     Toronto and East York      10       52  43.648944 -79.395587
# 4     Toronto and East York      10       52  43.648944 -79.395587
# ...                     ...     ...      ...        ...        ...
# 1774         Etobicoke York       5       12  43.703757 -79.523952
# 1775             North York       6       32  43.730696 -79.459316
# 1776             North York       6       32  43.730696 -79.459316
# 1777             North York       6       32  43.730696 -79.459316
# 1778            Scarborough      23       42  43.820048 -79.262058
#
#           LOCCOORD            ACCLOC        TRAFFCTL VISIBILITY  \
# 0     Intersection   At Intersection      No Control      Clear
# 1        Mid-Block            <Null>      No Control      Clear
# 2        Mid-Block            <Null>      No Control      Clear
# 3        Mid-Block            <Null>      No Control      Clear
# 4        Mid-Block            <Null>      No Control      Clear
# ...            ...               ...             ...        ...
# 1774  Intersection   At Intersection      No Control      Clear
# 1775     Mid-Block  Non Intersection      No Control      Clear
# 1776     Mid-Block  Non Intersection      No Control      Clear
# 1777     Mid-Block  Non Intersection      No Control      Clear
# 1778  Intersection   At Intersection  Traffic Signal       Rain
#
#                  LIGHT RDSFCOND           ACCLASS           IMPACTYPE  \
# 0             Daylight      Dry  Non-Fatal Injury  Cyclist Collisions
# 1     Dusk, artificial      Dry  Non-Fatal Injury         Approaching
# 2     Dusk, artificial      Dry  Non-Fatal Injury         Approaching
# 3     Dusk, artificial      Dry  Non-Fatal Injury         Approaching
# 4     Dusk, artificial      Dry  Non-Fatal Injury         Approaching
# ...                ...      ...               ...                 ...
# 1774  Dark, artificial      Dry  Non-Fatal Injury  Cyclist Collisions
# 1775          Daylight      Dry  Non-Fatal Injury  Cyclist Collisions
# 1776          Daylight      Dry  Non-Fatal Injury  Cyclist Collisions
# 1777          Daylight      Dry  Non-Fatal Injury  Cyclist Collisions
# 1778  Dusk, artificial      Wet  Non-Fatal Injury  Cyclist Collisions
#
#             INVTYPE    INVAGE  INJURY FATAL_NO INITDIR  \
# 0           Cyclist  40 to 44   Major   <Null>   South
# 1     Vehicle Owner   unknown  <Null>   <Null>  <Null>
# 2            Driver  25 to 29    None   <Null>    West
# 3         Passenger  55 to 59   Minor   <Null>  <Null>
# 4      Moped Driver  55 to 59   Major   <Null>    East
# ...             ...       ...     ...      ...     ...
# 1774        Cyclist  40 to 44   Major   <Null>    West
# 1775        Cyclist  30 to 34   Major   <Null>   South
# 1776         Driver  30 to 34    None   <Null>    East
# 1777      Passenger  45 to 49    None   <Null>  <Null>
# 1778        Cyclist  55 to 59   Major   <Null>    West
#
#                         VEHTYPE    MANOEUVER           DRIVACT DRIVCOND  \
# 0                       Bicycle  Going Ahead            <Null>   <Null>
# 1                        <Null>       <Null>            <Null>   <Null>
# 2                    Street Car  Going Ahead  Driving Properly   Normal
# 3                        <Null>       <Null>            <Null>   <Null>
# 4                         Moped  Going Ahead            <Null>   <Null>
# ...                         ...          ...               ...      ...
# 1774                    Bicycle  Going Ahead            <Null>   <Null>
# 1775                    Bicycle  Going Ahead            <Null>   <Null>
# 1776  Automobile, Station Wagon  Going Ahead  Driving Properly   Normal
# 1777                     <Null>       <Null>            <Null>   <Null>
# 1778                    Bicycle  Going Ahead            <Null>   <Null>
#
#      PEDTYPE  PEDACT PEDCOND  \
# 0     <Null>  <Null>  <Null>
# 1     <Null>  <Null>  <Null>
# 2     <Null>  <Null>  <Null>
# 3     <Null>  <Null>  <Null>
# 4     <Null>  <Null>  <Null>
# ...      ...     ...     ...
# 1774  <Null>  <Null>  <Null>
# 1775  <Null>  <Null>  <Null>
# 1776  <Null>  <Null>  <Null>
# 1777  <Null>  <Null>  <Null>
# 1778  <Null>  <Null>  <Null>
#
#                                              CYCLISTYPE  \
# 0            Motorist turned left across cyclists path.
# 1                                                <Null>
# 2                                                <Null>
# 3                                                <Null>
# 4                                                <Null>
# ...                                                 ...
# 1774         Motorist turned left across cyclists path.
# 1775  Cyclist without ROW rides into path of motoris...
# 1776                                             <Null>
# 1777                                             <Null>
# 1778  Cyclist without ROW rides into path of motoris...
#
#                             CYCACT      CYCCOND PEDESTRIAN CYCLIST AUTOMOBILE  \
# 0                 Driving Properly       Normal     <Null>     Yes        Yes
# 1                           <Null>       <Null>     <Null>     Yes     <Null>
# 2                           <Null>       <Null>     <Null>     Yes     <Null>
# 3                           <Null>       <Null>     <Null>     Yes     <Null>
# 4                           <Null>       <Null>     <Null>     Yes     <Null>
# ...                            ...          ...        ...     ...        ...
# 1774              Driving Properly       Normal     <Null>     Yes        Yes
# 1775  Failed to Yield Right of Way  Inattentive     <Null>     Yes        Yes
# 1776                        <Null>       <Null>     <Null>     Yes        Yes
# 1777                        <Null>       <Null>     <Null>     Yes        Yes
# 1778     Disobeyed Traffic Control      Unknown     <Null>     Yes        Yes
#
#      MOTORCYCLE   TRUCK TRSN_CITY_VEH EMERG_VEH PASSENGER SPEEDING AG_DRIV  \
# 0        <Null>  <Null>        <Null>    <Null>    <Null>   <Null>     Yes
# 1        <Null>  <Null>           Yes    <Null>       Yes   <Null>  <Null>
# 2        <Null>  <Null>           Yes    <Null>       Yes   <Null>  <Null>
# 3        <Null>  <Null>           Yes    <Null>       Yes   <Null>  <Null>
# 4        <Null>  <Null>           Yes    <Null>       Yes   <Null>  <Null>
# ...         ...     ...           ...       ...       ...      ...     ...
# 1774     <Null>  <Null>        <Null>    <Null>    <Null>   <Null>  <Null>
# 1775     <Null>  <Null>        <Null>    <Null>       Yes   <Null>  <Null>
# 1776     <Null>  <Null>        <Null>    <Null>       Yes   <Null>  <Null>
# 1777     <Null>  <Null>        <Null>    <Null>       Yes   <Null>  <Null>
# 1778     <Null>  <Null>        <Null>    <Null>    <Null>   <Null>  <Null>
#
#      REDLIGHT ALCOHOL DISABILITY POLICE_DIVISION  HOOD_ID  \
# 0      <Null>  <Null>     <Null>             D12      111
# 1      <Null>  <Null>     <Null>             D52       78
# 2      <Null>  <Null>     <Null>             D52       78
# 3      <Null>  <Null>     <Null>             D52       78
# 4      <Null>  <Null>     <Null>             D52       78
# ...       ...     ...        ...             ...      ...
# 1774   <Null>  <Null>     <Null>             D12      113
# 1775   <Null>  <Null>     <Null>             D32       26
# 1776   <Null>  <Null>     <Null>             D32       26
# 1777   <Null>  <Null>     <Null>             D32       26
# 1778   <Null>  <Null>     <Null>             D42      130
#
#                   NEIGHBOURHOOD  ObjectId
# 0       Rockcliffe-Smythe (111)         1
# 1     Kensington-Chinatown (78)         2
# 2     Kensington-Chinatown (78)         3
# 3     Kensington-Chinatown (78)         4
# 4     Kensington-Chinatown (78)         5
# ...                         ...       ...
# 1774               Weston (113)      1775
# 1775  Downsview-Roding-CFB (26)      1776
# 1776  Downsview-Roding-CFB (26)      1777
# 1777  Downsview-Roding-CFB (26)      1778
# 1778             Milliken (130)      1779
#
# [1779 rows x 55 columns]

# %%
print(cyclist.dtypes)
# Out:
# INDEX_               int64
# ACCNUM               int64
# YEAR                 int64
# DATE                object
# TIME                 int64
# HOUR                 int64
# STREET1             object
# STREET2             object
# OFFSET              object
# ROAD_CLASS          object
# DISTRICT            object
# WARDNUM             object
# DIVISION            object
# LATITUDE           float64
# LONGITUDE          float64
# LOCCOORD            object
# ACCLOC              object
# TRAFFCTL            object
# VISIBILITY          object
# LIGHT               object
# RDSFCOND            object
# ACCLASS             object
# IMPACTYPE           object
# INVTYPE             object
# INVAGE              object
# INJURY              object
# FATAL_NO            object
# INITDIR             object
# VEHTYPE             object
# MANOEUVER           object
# DRIVACT             object
# DRIVCOND            object
# PEDTYPE             object
# PEDACT              object
# PEDCOND             object
# CYCLISTYPE          object
# CYCACT              object
# CYCCOND             object
# PEDESTRIAN          object
# CYCLIST             object
# AUTOMOBILE          object
# MOTORCYCLE          object
# TRUCK               object
# TRSN_CITY_VEH       object
# EMERG_VEH           object
# PASSENGER           object
# SPEEDING            object
# AG_DRIV             object
# REDLIGHT            object
# ALCOHOL             object
# DISABILITY          object
# POLICE_DIVISION     object
# HOOD_ID              int64
# NEIGHBOURHOOD       object
# ObjectId             int64
# dtype: object
